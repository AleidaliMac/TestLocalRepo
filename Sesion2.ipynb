# %%
import requests  #jij
import os
def load(xml):
   CATEGORY="Products"
   FILENAME=xml
   url = "http://vasco-api-gateway.vasco-s1.a.westeurope.blue-yonder.cloud/delivery"
   auth = ("techadmin@professional-services.jda.com", "HhH.~hnkDl,i>j}/Smhze3T[Y4b-PD:j")
   content_type="text/xml"
   data=dict(TenantID="7145d3b9-5a69-452b-b5af-9dfddeaa66ae",Category=CATEGORY)
   files=dict(Data=(os.path.basename(FILENAME), open(FILENAME), content_type))
   response=requests.post(url, auth=auth, data=data, files=files)
   print(response.text)

xml="/Users/1031272/Desktop/Training/Products.xml"
load(xml)
# Out:
# <?xml version='1.0' encoding='UTF-8'?>
# <DeliveryStatus>
#   <DeliveryID>1774</DeliveryID>
#   <StartDelivery>2021-10-28T21:12:29.352326Z</StartDelivery>
#   <LastProcessed>2021-10-28T21:12:29.352326Z</LastProcessed>
#   <ParameterInfo>
#     <Category>Products</Category>
#     <Version>1.14.42</Version>
#     <File>Products.xml</File>
#   </ParameterInfo>
#   <Status>ACCEPTED</Status>
# </DeliveryStatus>
